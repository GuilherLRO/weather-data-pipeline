# %%
# !ls
# Out:
# docker-compose.yaml

# %%
# %cd metabase-docker
# Out:
# [Errno 2] No such file or directory: 'metabase-docker'
# /home/guilherme/glro_git/airflow_first_project/metabase-docker

# %%
# !docker-compose up
# Out:
# Recreating metabase ...
# Attaching to metabasedone
# metabase    | Warning: environ value jdk-11.0.21+9 for key :java-version has been overwritten with 11.0.21
# metabase    | 2024-01-08 19:44:28,188 INFO metabase.util :: Maximum memory available to JVM: 3.9 GB
# metabase    | 2024-01-08 19:44:30,457 WARN db.env :: WARNING: Using Metabase with an H2 application database is not recommended for production deployments. For production deployments, we highly recommend using Postgres, MySQL, or MariaDB instead. If you decide to continue to use H2, please be sure to back up the database file regularly. For more information, see https://metabase.com/docs/latest/operations-guide/migrating-from-h2.html
# metabase    | 2024-01-08 19:44:30,632 INFO util.encryption :: Saved credentials encryption is DISABLED for this Metabase instance. 🔓
# metabase    |  For more information, see https://metabase.com/docs/latest/operations-guide/encrypting-database-details-at-rest.html
# ...

# %%
#docker container inspect 26e1300965ca
